# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

image = cv.imread('store/store_shelf.png',cv.IMREAD_REDUCED_COLOR_2)
assert image is not None
template = cv.imread('store/oat_crunch.jpg',cv.IMREAD_REDUCED_COLOR_2)
assert template is not None

sift = cv.SIFT_create()
kp1, des1 = sift.detectAndCompute(image, None)
kp2, des2 = sift.detectAndCompute(template, None)

FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks=50)  
flann = cv.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(des1, des2, k=2)


matchesMask = [[0,0] for i in range(len(matches))]


for i, (m,n) in enumerate(matches):
    if m.distance < 0.7*n.distance:
        matchesMask[i]=[1,0]

draw_params = dict(matchColor = (0, 255, 0), singlePointColor = (255, 0, 0), matchesMask = matchesMask, flags = cv.DrawMatchesFlags_DEFAULT)
img3 = cv.drawMatchesKnn(image, kp1, template, kp2, matches, None, **draw_params)
plt.imshow(cv.cvtColor(img3, cv.COLOR_BGR2RGB))
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

image2 = cv.imread('harry_potter/shelf.jpg',cv.IMREAD_REDUCED_COLOR_2)
assert image2 is not None
template2 = cv.imread('harry_potter/book.jpg',cv.IMREAD_REDUCED_COLOR_2)
assert template2 is not None

fig , axes2 = plt.subplots(1,1)

axes2.imshow(X=image2)
axes2.axis('off')
axes2.set_title('Book Shelf')

fig , axes2 = plt.subplots(1,1)

axes2.imshow(X=template2)
axes2.axis('off')
axes2.set_title("Book")

plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

image2 = cv.imread('harry_potter/shelf.jpg',cv.IMREAD_REDUCED_COLOR_2)
assert image2 is not None
template2 = cv.imread('harry_potter/book.jpg',cv.IMREAD_REDUCED_COLOR_2)
assert template2 is not None

sift = cv.SIFT_create()
kp1, des1 = sift.detectAndCompute(image2, None)
kp2, des2 = sift.detectAndCompute(template2, None)

FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks=50)  
flann = cv.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(des1, des2, k=2)


matchesMask = [[0,0] for i in range(len(matches))]


for i, (m,n) in enumerate(matches):
    if m.distance < 0.7*n.distance:
        matchesMask[i]=[1,0]

draw_params = dict(matchColor = (0, 255, 0), singlePointColor = (255, 0, 0), matchesMask = matchesMask, flags = cv.DrawMatchesFlags_DEFAULT)
img3 = cv.drawMatchesKnn(image2, kp1, template2, kp2, matches, None, **draw_params)
plt.imshow(cv.cvtColor(img3, cv.COLOR_BGR2RGB))
plt.show()
